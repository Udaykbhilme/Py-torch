# %%
import torch

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.5
# comm                      0.2.3
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.25.2
# fqdn                      1.5.1
# fsspec                    2026.2.0
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# ipykernel                 7.2.0
# ipython                   9.11.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.6
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# lark                      1.3.1
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.1
# mistune                   3.2.0
# mpmath                    1.3.0
# nbclient                  0.10.4
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.6.1
# notebook_shim             0.2.4
# numpy                     2.4.3
# packaging                 26.0
# pandocfilters             1.5.1
# parso                     0.8.6
# pexpect                   4.9.0
# pillow                    12.1.1
# pip                       26.0
# platformdirs              4.9.4
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 3.0
# Pygments                  2.19.2
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.30.0
# Send2Trash                2.1.0
# setuptools                82.0.1
# six                       1.17.0
# soupsieve                 2.8.3
# stack-data                0.6.3
# sympy                     1.14.0
# terminado                 0.18.1
# tinycss2                  1.4.0
# torch                     2.10.0
# torchaudio                2.10.0
# torchvision               0.25.0
# tornado                   6.5.5
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# wcwidth                   0.6.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0

# %%
pip install jupyterlab-git
# Out:
# Collecting jupyterlab-git
#   Downloading jupyterlab_git-0.52.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in ./venv/lib/python3.14/site-packages (from jupyterlab-git) (2.17.0)
# Collecting nbdime~=4.0.1 (from jupyterlab-git)
#   Downloading nbdime-4.0.4-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: nbformat in ./venv/lib/python3.14/site-packages (from jupyterlab-git) (5.10.4)
# Requirement already satisfied: packaging in ./venv/lib/python3.14/site-packages (from jupyterlab-git) (26.0)
# Requirement already satisfied: pexpect in ./venv/lib/python3.14/site-packages (from jupyterlab-git) (4.9.0)
# Requirement already satisfied: traitlets~=5.0 in ./venv/lib/python3.14/site-packages (from jupyterlab-git) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (7.17.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (6.5.5)
# Requirement already satisfied: websocket-client>=1.7 in ./venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.9.0)
# Collecting colorama (from nbdime~=4.0.1->jupyterlab-git)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting gitpython!=2.1.4,!=2.1.5,!=2.1.6 (from nbdime~=4.0.1->jupyterlab-git)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pygments in ./venv/lib/python3.14/site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.19.2)
# Requirement already satisfied: requests in ./venv/lib/python3.14/site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.32.5)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.14/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.11)
# Requirement already satisfied: argon2-cffi-bindings in ./venv/lib/python3.14/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.1.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.14/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.14/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.9.4)
# Requirement already satisfied: jsonschema>=4.18.0 in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.26.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in ./venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.0.3)
# Requirement already satisfied: referencing in ./venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.37.0)
# Requirement already satisfied: rfc3339-validator in ./venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in ./venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.30.0)
# Requirement already satisfied: fqdn in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.1)
# Requirement already satisfied: isoduration in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.1.0)
# Requirement already satisfied: uri-template in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in ./venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.3.0)
# Requirement already satisfied: defusedxml in ./venv/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./venv/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./venv/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in ./venv/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./venv/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.1)
# Requirement already satisfied: webencodings in ./venv/lib/python3.14/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./venv/lib/python3.14/site-packages (from nbformat->jupyterlab-git) (2.21.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in ./venv/lib/python3.14/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.1)
# Requirement already satisfied: ptyprocess in ./venv/lib/python3.14/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.0)
# Requirement already satisfied: cffi>=2.0.0b1 in ./venv/lib/python3.14/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.0.0)
# Requirement already satisfied: pycparser in ./venv/lib/python3.14/site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in ./venv/lib/python3.14/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.14/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in ./venv/lib/python3.14/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: tzdata in ./venv/lib/python3.14/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.14/site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.14/site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.14/site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2026.2.25)
# Downloading jupyterlab_git-0.52.0-py3-none-any.whl (370 kB)
# Downloading nbdime-4.0.4-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 4.1 MB/s  0:00:01m 4.1 MB/s eta 0:00:01
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: smmap, colorama, gitdb, gitpython, nbdime, jupyterlab-git
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [jupyterlab-git] 5/6 [jupyterlab-git]
# Successfully installed colorama-0.4.6 gitdb-4.0.12 gitpython-3.1.46 jupyterlab-git-0.52.0 nbdime-4.0.4 smmap-5.0.3
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter lab build
# Out:
#   Cell In[4], line 1
#     jupyter lab build
#             ^
# SyntaxError: invalid syntax

# %%
git --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 git --version
#
# NameError: name 'git' is not defined

# %%
# !git --version
# Out:
# git version 2.50.1 (Apple Git-155)

# %%
# !git init
# Out:
# Initialized empty Git repository in /Users/udaykumarbhilme/Desktop/pytorch/.git/

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# [main (root-commit) 79dfb17] first commit
#  2 files changed, 318 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb

# %%
# !git remote add origin https://github.com/Udaykbhilme/Py-torch.git

# %%
# !git push -u origin main
# Out:
# To https://github.com/Udaykbhilme/Py-torch.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/Udaykbhilme/Py-torch.git'
# hint: Updates were rejected because the remote contains work that you do not
# hint: have locally. This is usually caused by another repository pushing to
# hint: the same ref. If you want to integrate the remote changes, use
# hint: 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.57 KiB | 134.00 KiB/s, done.
# From https://github.com/Udaykbhilme/Py-torch
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.

# %%
# !git push -u origin main
# Out:
# To https://github.com/Udaykbhilme/Py-torch.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/Udaykbhilme/Py-torch.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. If you want to integrate the remote changes,
# hint: use 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# [main 2837e4d] first commit
#  1 file changed, 71 insertions(+), 2 deletions(-)

# %%
# !git push origin main
# Out:
# To https://github.com/Udaykbhilme/Py-torch.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/Udaykbhilme/Py-torch.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. If you want to integrate the remote changes,
# hint: use 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git add .
# !git rebase --continue
# Out:
# fatal: no rebase in progress

# %%
# !git pull origin main --rebase
# Out:
# error: cannot pull with rebase: Your index contains uncommitted changes.
# error: Please commit or stash them.
