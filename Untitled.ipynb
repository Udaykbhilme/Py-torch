# %%
import torch

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.2.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.2.25
# cffi                      2.0.0
# charset-normalizer        3.4.5
# comm                      0.2.3
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.25.2
# fqdn                      1.5.1
# fsspec                    2026.2.0
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# ...

# %%
pip install jupyterlab-git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 4.1 MB/s  0:00:01m 4.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [jupyterlab-git] 5/6 [jupyterlab-git]
# ...
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter lab build
# Out:
#   Cell In[4], line 1
#     jupyter lab build
#             ^
# SyntaxError: invalid syntax

# %%
git --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 git --version
#
# NameError: name 'git' is not defined
